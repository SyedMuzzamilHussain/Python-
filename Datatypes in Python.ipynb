# %%
a = 5
b = 3
sum = a + b
print("Sum of", a, "and", b, "is", sum)
# Out:
# Sum of 5 and 3 is 8

# %%
x = 7
y = 4
product = x * y
print("Multiplication of", x, "and", y, "is", product)
# Out:
# Product of 7 and 4 is 28

# %%
a = int(input("Enter the first integer: "))
b = int(input("Enter the second integer: "))
sum = a + b
print("Sum of", a, "and", b, "is", sum)
# Out:
# Enter the first integer: 23
# Enter the second integer: 45
# Sum of 23 and 45 is 68

# %%
x = int(input("Enter the first integer: "))
y = int(input("Enter the second integer: "))
difference = x - y
print("Subtraction between", x, "and", y, "is", difference)
# Out:
# Enter the first integer: 56
# Enter the second integer: 34
# Subtraction between 56 and 34 is 22

# %%
# Float Examples :

a = 2.5
b = 3.7
sum = a + b
print("Sum of", a, "and", b, "is", sum)
# Out:
# Sum of 2.5 and 3.7 is 6.2

# %%
x = 5.4
y = 2.0
result = x / y
print("Division of", x, "by", y, "gives", result)
# Out:
# Division of 5.4 by 2.0 gives 2.7

# %%
a = float(input("Enter the first float: "))
b = float(input("Enter the second float: "))
product = a * b
print("Multiplication of", a, "and", b, "is", product)
# Out:
# Enter the first float: 35
# Enter the second float: 35
# Multiplication of 35.0 and 35.0 is 1225.0

# %%
x = float(input("Enter the first float: "))
y = float(input("Enter the second float: "))
difference = x - y
print("Subtraction between", x, "and", y, "is", difference)
# Out:
# Enter the first float: 465
# Enter the second float: 34
# Subtraction between 465.0 and 34.0 is 431.0

# %%
# Character

char = 'A'
print("The character is", char)
# Out:
# The character is A

# %%
char = input("Enter a character: ")
print("You entered the character:", char)
# Out:
# Enter a character: Y
# You entered the character: Y

# %%
# Boolean Question

a=35
b=23
print(a>b)
# Out:
# True

# %%
a=46
b=45
print(a==b)
# Out:
# False
